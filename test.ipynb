# %%
import pandas
import numpy as np

df = pandas.read_csv("../data/data_food_final.csv")
query = 'coca cherry'
isinside =  (df['product_name'].str.contains('coca', case=False) & df['product_name'].str.contains('cherry', case=False))
isinside
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 168438    False
# 168439    False
# 168440    False
# 168441    False
# 168442    False
# 168443    False
# 168444    False
# 168445    False
# 168446    False
# 168447    False
# 168448    False
# 168449    False
# 168450    False
# 168451    False
# 168452    False
# 168453    False
# 168454    False
# 168455    False
# 168456    False
# 168457    False
# 168458    False
# 168459    False
# 168460    False
# 168461    False
# ...

# %%
isinside = df['product_name'].str.contains('', case=False)

all(isinside)
# Out:
# True

# %%
for item in query.split():
    isinside = isinside & df['product_name'].str.contains(item, case=False)
df[isinside]
# Out:
#                  code                    product_name  \
# 38      0000054492790  Blle Pet 50CL Coca Cola Cherry
# 137765  5449000000491                Coca-cola cherry
# 137769  5449000000897                Coca-Cola Cherry
# 137786  5449000009500                Coca-Cola cherry
# 137787  5449000009920                Coca Cola Cherry
# 137814  5449000024312                Coca-Cola cherry
# 137915  5449000109255                Coca Cola Cherry
# 138011  5449000185945                Coca Cola Cherry
# 138023  5449000195340           Coca cola zero cherry
# 138024  5449000195364           Coca-Cola Zero Cherry
# 138025  5449000195371           Coca-Cola Zero Cherry
# 138029  5449000197092                     Coca Cherry
# 138067  5449000214843                Coca-Cola Cherry
# 138087  5449000223586           Coca-cola zéro cherry
# 138091  5449000223982           Coca cola mini cherry
# 138096  5449000224200     Coca cola cherry zéro sugar
# ...

# %%
for row in df.itertuples():
    if row[2].str.contains('saumon', case=False)[0]:
        print(row[2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-f6cb6faf36e5> in <module>()
#       1 for row in df.itertuples():
# ----> 2     if row[2].str.contains('saumon', case=False)[0]:
#       3         print(row[2])
#
# AttributeError: 'str' object has no attribute 'str'

# %%
df[isinside]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-486728dc90f8> in <module>()
#       1
# ----> 2 df[isinside]
#
# ~\Anaconda3\envs\ada\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~\Anaconda3\envs\ada\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2717             elif len(key) != len(self.index):
#    2718                 raise ValueError('Item wrong length %d instead of %d.' %
# -> 2719                                  (len(key), len(self.index)))
# ...

# %%
dict = {'a':{'first':'', 'second':''}, 'b':{'first':'', 'second':''}}
dict['a']['first'] = 1
dict['a']['second'] = 2
dict['b']['first'] = 3
dict['b']['second'] = 4
import pandas as pd
pd.DataFrame.from_dict(dict)
# Out:
#         a  b
# first   1  3
# second  2  4

# %%
df_patients = pd.DataFrame(
            {'patient_code': [1001111, 1001112, 1001113],
             'consultation_list': [{10120010, 10120011, 10120012, 10120013}, \
             {10120021}, {10120031, 10120032}]},
        )
df_patients.set_index('patient_code', inplace=True)
df_patients.to_csv('df_patients.csv')

# %%
data = [{'label1': {'text' : '1234'}}, {'label1': {'text': '5678'}}]
product = {'code': ['1234', '5678']}

data[0]['label1']['text'] == product['code'][0] and data[1]['label1']['text'] == product['code'][1]
# Out:
# True

# %%
listTest = [0,1,2]

index = 2
quantity = 999
l = len(listTest)
if index < l:
    listTest[index] = quantity
else:
    temp = [0 for i in range(index-l)]
    listTest = listTest + temp + [quantity]


listTest
# Out:
# [0, 1, 999]

# %%
teststring = '     '
len(teststring.strip())
# Out:
# 0

# %%
dict = {'a':[1,2], 'b':[12,13]}
import pandas as pd
df_test = pd.DataFrame.from_dict(dict)
df_test
# Out:
#    a   b
# 0  1  12
# 1  2  13

# %%
df2 = pd.DataFrame.from_dict({'index': len(df_test), 'a': ['3'], 'b': ['4']}).set_index('index')
df_test.append(df2)
# Out:
#    a   b
# 0  1  12
# 1  2  13
# 2  3   4
